# %% [markdown]
# # Self-Attention Graph Pooling (SAGP) reproducing code
# Author: 'Yeongtak Oh'

# %% [markdown]
# * (Original) highly-cited by 'https://github.com/inyeoplee77/SAGPool'
# * torch-geometric : 'https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#torch_geometric.nn.pool.SAGPooling'

# %%
import torch
from torch_geometric.datasets import TUDataset
from torch_geometric.data import DataLoader
from torch_geometric import utils
from networks import  Net
import torch.nn.functional as F
import argparse
import os
from torch.utils.data import random_split
import easydict

# dataset selection: AIDS, DD, 
args = easydict.EasyDict({"seed": 777, 
                          "batch_size": 128, 
                          "lr": 0.0005, 
                          "weight_decay": 0.0001, 
                          "nhid": 128, 
                          "pooling_ratio": 0.5, 
                          "dropout_ratio": 0.5, 
                          "dataset": 'FIRSTMM_DB', 
                          "epochs": 100000, 
                          "patience": 50, 
                          "pooling_layer_type":'GCNConv'})

# %%
# device setting
torch.manual_seed(args.seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(args.seed)
    args.device = 'cuda:0'
    
# data load
dataset = TUDataset(os.path.join('data',args.dataset),name=args.dataset)
args.num_classes = dataset.num_classes
args.num_features = dataset.num_features
num_training = int(len(dataset)*0.8)
num_val = int(len(dataset)*0.1)
num_test = len(dataset) - (num_training+num_val)
training_set,validation_set,test_set = random_split(dataset,[num_training,num_val,num_test])
# Out:
# Downloading https://ls11-www.cs.tu-dortmund.de/people/morris/graphkerneldatasets/FIRSTMM_DB.zip
# Extracting data/FIRSTMM_DB/FIRSTMM_DB/FIRSTMM_DB.zip
# Processing...
# Done!

# %%
# data loader & model setup
train_loader = DataLoader(training_set, batch_size=args.batch_size, shuffle=True)
val_loader = DataLoader(validation_set,batch_size=args.batch_size, shuffle=False)
test_loader = DataLoader(test_set,batch_size=1, shuffle=False)
model = Net(args).to(args.device)
optimizer = torch.optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.weight_decay)

def test(model,loader):
    model.eval()
    correct = 0.
    loss = 0.
    for data in loader:
        data = data.to(args.device)
        out = model(data)
        pred = out.max(dim=1)[1]
        correct += pred.eq(data.y).sum().item()
        loss += F.nll_loss(out,data.y,reduction='sum').item()
    return correct / len(loader.dataset),loss / len(loader.dataset)

min_loss = 1e10
patience = 0
val_loss_plot = []
val_acc_plot = []
args.epochs = 100
for epoch in range(args.epochs):
    print("\n")
    print("====== epoch {} ======".format(epoch))
    model.train()
    for i, data in enumerate(train_loader):
        data = data.to(args.device)
        out = model(data)
        loss = F.nll_loss(out, data.y)
        print("Training loss:{:.3f}".format(loss.item()))
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    val_acc,val_loss = test(model,val_loader)
    print("Validation loss:{:.3f}\taccuracy:{:.3f}".format(val_loss,val_acc))
    if val_loss < min_loss:
        torch.save(model.state_dict(),'latest.pth')
        print("Model saved at epoch{}".format(epoch))
        min_loss = val_loss
        patience = 0
    else:
        patience += 1
    if patience > args.patience:
        break 
    val_loss_plot.append(val_loss)
    val_acc_plot.append(val_acc)

model = Net(args).to(args.device)
model.load_state_dict(torch.load('latest.pth'))
test_acc,test_loss = test(model,test_loader)
print("Test accuarcy:{}".fotmat(test_acc))
# Out:
# ====== epoch 0 ======
# Training loss:2.407
# Validation loss:2.373	accuracy:0.250
# Model saved at epoch0
#
#
# ====== epoch 1 ======
# Training loss:2.407
# Validation loss:2.373	accuracy:0.250
#
#
# ====== epoch 2 ======
# Training loss:2.407
# Validation loss:2.374	accuracy:0.250
#
#
# ====== epoch 3 ======
# Training loss:2.405
# Validation loss:2.375	accuracy:0.250
#
#
# ====== epoch 4 ======
# Training loss:2.404
# Validation loss:2.375	accuracy:0.250
#
#
# ====== epoch 5 ======
# Training loss:2.404
# Validation loss:2.376	accuracy:0.250
#
#
# ====== epoch 6 ======
# Training loss:2.402
# Validation loss:2.376	accuracy:0.250
#
#
# ====== epoch 7 ======
# Training loss:2.401
# Validation loss:2.377	accuracy:0.250
#
#
# ====== epoch 8 ======
# Training loss:2.400
# Validation loss:2.377	accuracy:0.250
#
#
# ====== epoch 9 ======
# Training loss:2.400
# Validation loss:2.378	accuracy:0.250
#
#
# ====== epoch 10 ======
# Training loss:2.399
# Validation loss:2.378	accuracy:0.250
#
#
# ====== epoch 11 ======
# Training loss:2.398
# Validation loss:2.379	accuracy:0.250
#
#
# ====== epoch 12 ======
# Training loss:2.398
# Validation loss:2.379	accuracy:0.250
#
#
# ====== epoch 13 ======
# Training loss:2.397
# Validation loss:2.380	accuracy:0.250
#
#
# ====== epoch 14 ======
# Training loss:2.395
# Validation loss:2.381	accuracy:0.250
#
#
# ====== epoch 15 ======
# Training loss:2.396
# Validation loss:2.381	accuracy:0.250
#
#
# ====== epoch 16 ======
# Training loss:2.393
# Validation loss:2.382	accuracy:0.250
#
#
# ====== epoch 17 ======
# Training loss:2.391
# Validation loss:2.382	accuracy:0.250
#
#
# ====== epoch 18 ======
# Training loss:2.391
# Validation loss:2.383	accuracy:0.250
#
#
# ====== epoch 19 ======
# Training loss:2.389
# Validation loss:2.383	accuracy:0.250
#
#
# ====== epoch 20 ======
# Training loss:2.389
# Validation loss:2.384	accuracy:0.250
#
#
# ====== epoch 21 ======
# Training loss:2.389
# Validation loss:2.384	accuracy:0.250
#
#
# ====== epoch 22 ======
# Training loss:2.387
# Validation loss:2.384	accuracy:0.250
#
#
# ====== epoch 23 ======
# Training loss:2.387
# Validation loss:2.385	accuracy:0.250
#
#
# ====== epoch 24 ======
# Training loss:2.383
# Validation loss:2.385	accuracy:0.250
#
#
# ====== epoch 25 ======
# Training loss:2.385
# Validation loss:2.386	accuracy:0.250
#
#
# ====== epoch 26 ======
# Training loss:2.378
# Validation loss:2.386	accuracy:0.250
#
#
# ====== epoch 27 ======
# Training loss:2.381
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 28 ======
# Training loss:2.378
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 29 ======
# Training loss:2.378
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 30 ======
# Training loss:2.375
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 31 ======
# Training loss:2.374
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 32 ======
# Training loss:2.366
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 33 ======
# Training loss:2.368
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 34 ======
# Training loss:2.364
# Validation loss:2.387	accuracy:0.250
#
#
# ====== epoch 35 ======
# Training loss:2.364
# Validation loss:2.386	accuracy:0.250
#
#
# ====== epoch 36 ======
# Training loss:2.362
# Validation loss:2.386	accuracy:0.250
#
#
# ====== epoch 37 ======
# Training loss:2.356
# Validation loss:2.386	accuracy:0.250
#
#
# ====== epoch 38 ======
# Training loss:2.356
# Validation loss:2.385	accuracy:0.250
#
#
# ====== epoch 39 ======
# Training loss:2.351
# Validation loss:2.384	accuracy:0.250
#
#
# ====== epoch 40 ======
# Training loss:2.343
# Validation loss:2.383	accuracy:0.250
#
#
# ====== epoch 41 ======
# Training loss:2.333
# Validation loss:2.383	accuracy:0.250
#
#
# ====== epoch 42 ======
# Training loss:2.336
# Validation loss:2.382	accuracy:0.250
#
#
# ====== epoch 43 ======
# Training loss:2.330
# Validation loss:2.380	accuracy:0.250
#
#
# ====== epoch 44 ======
# Training loss:2.324
# Validation loss:2.379	accuracy:0.250
#
#
# ====== epoch 45 ======
# Training loss:2.315
# Validation loss:2.377	accuracy:0.250
#
#
# ====== epoch 46 ======
# Training loss:2.305
# Validation loss:2.376	accuracy:0.250
#
#
# ====== epoch 47 ======
# Training loss:2.301
# Validation loss:2.374	accuracy:0.250
#
#
# ====== epoch 48 ======
# Training loss:2.295
# Validation loss:2.371	accuracy:0.250
# Model saved at epoch48
#
#
# ====== epoch 49 ======
# Training loss:2.283
# Validation loss:2.368	accuracy:0.250
# Model saved at epoch49
#
#
# ====== epoch 50 ======
# Training loss:2.265
# Validation loss:2.364	accuracy:0.250
# Model saved at epoch50
#
#
# ====== epoch 51 ======
# Training loss:2.263
# Validation loss:2.360	accuracy:0.250
# Model saved at epoch51
#
#
# ====== epoch 52 ======
# Training loss:2.250
# Validation loss:2.356	accuracy:0.250
# Model saved at epoch52
#
#
# ====== epoch 53 ======
# Training loss:2.220
# Validation loss:2.351	accuracy:0.250
# Model saved at epoch53
#
#
# ====== epoch 54 ======
# Training loss:2.191
# Validation loss:2.347	accuracy:0.250
# Model saved at epoch54
#
#
# ====== epoch 55 ======
# Training loss:2.201
# Validation loss:2.341	accuracy:0.250
# Model saved at epoch55
#
#
# ====== epoch 56 ======
# Training loss:2.168
# Validation loss:2.336	accuracy:0.250
# Model saved at epoch56
#
#
# ====== epoch 57 ======
# Training loss:2.155
# Validation loss:2.330	accuracy:0.250
# Model saved at epoch57
#
#
# ====== epoch 58 ======
# Training loss:2.104
# Validation loss:2.323	accuracy:0.250
# Model saved at epoch58
#
#
# ====== epoch 59 ======
# Training loss:2.105
# Validation loss:2.315	accuracy:0.000
# Model saved at epoch59
#
#
# ====== epoch 60 ======
# Training loss:2.069
# Validation loss:2.309	accuracy:0.000
# Model saved at epoch60
#
#
# ====== epoch 61 ======
# Training loss:2.070
# Validation loss:2.300	accuracy:0.000
# Model saved at epoch61
#
#
# ====== epoch 62 ======
# Training loss:2.007
# Validation loss:2.293	accuracy:0.000
# Model saved at epoch62
#
#
# ====== epoch 63 ======
# Training loss:1.989
# Validation loss:2.287	accuracy:0.000
# Model saved at epoch63
#
#
# ====== epoch 64 ======
# Training loss:1.993
# Validation loss:2.281	accuracy:0.000
# Model saved at epoch64
#
#
# ====== epoch 65 ======
# Training loss:1.967
# Validation loss:2.276	accuracy:0.000
# Model saved at epoch65
#
#
# ====== epoch 66 ======
# Training loss:1.960
# Validation loss:2.277	accuracy:0.000
#
#
# ====== epoch 67 ======
# Training loss:1.893
# Validation loss:2.280	accuracy:0.000
#
#
# ====== epoch 68 ======
# Training loss:1.866
# Validation loss:2.285	accuracy:0.000
#
#
# ====== epoch 69 ======
# Training loss:1.872
# Validation loss:2.293	accuracy:0.000
#
#
# ====== epoch 70 ======
# Training loss:1.870
# Validation loss:2.304	accuracy:0.000
#
#
# ====== epoch 71 ======
# Training loss:1.854
# Validation loss:2.314	accuracy:0.000
#
#
# ====== epoch 72 ======
# Training loss:1.786
# Validation loss:2.326	accuracy:0.000
#
#
# ====== epoch 73 ======
# Training loss:1.785
# Validation loss:2.341	accuracy:0.000
#
#
# ====== epoch 74 ======
# Training loss:1.763
# Validation loss:2.361	accuracy:0.000
#
#
# ====== epoch 75 ======
# Training loss:1.754
# Validation loss:2.379	accuracy:0.000
#
#
# ====== epoch 76 ======
# Training loss:1.695
# Validation loss:2.398	accuracy:0.000
#
#
# ====== epoch 77 ======
# Training loss:1.747
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-59-c164b62758aa> in <module>
#      35         optimizer.step()
#      36         optimizer.zero_grad()
# ---> 37     val_acc,val_loss = test(model,val_loader)
#      38     print("Validation loss:{:.3f}\taccuracy:{:.3f}".format(val_loss,val_acc))
#      39     if val_loss < min_loss:
#
# <ipython-input-59-c164b62758aa> in test(model, loader)
#      12     for data in loader:
#      13         data = data.to(args.device)
# ---> 14         out = model(data)
#      15         pred = out.max(dim=1)[1]
#      16         correct += pred.eq(data.y).sum().item()
#
# ~/pytorch_geometric/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/pytorch_geometric/yeongtak_data/networks.py in forward(self, data)
#      39
#      40         x = F.relu(self.conv2(x, edge_index))
# ---> 41         x, edge_index, _, batch, _ = self.pool2(x, edge_index, None, batch)
#      42         x2 = torch.cat([gmp(x, batch), gap(x, batch)], dim=1)
#      43
#
# ~/pytorch_geometric/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/pytorch_geometric/yeongtak_data/layers.py in forward(self, x, edge_index, edge_attr, batch)
#      22         batch = batch[perm]
#      23         edge_index, edge_attr = filter_adj(
# ---> 24             edge_index, edge_attr, perm, num_nodes=score.size(0))
#      25
#      26         return x, edge_index, edge_attr, batch, perm
#
# ~/pytorch_geometric/venv/lib/python3.6/site-packages/torch_geometric/nn/pool/topk_pool.py in filter_adj(edge_index, edge_attr, perm, num_nodes)
#      51
#      52     mask = perm.new_full((num_nodes, ), -1)
# ---> 53     i = torch.arange(perm.size(0), dtype=torch.long, device=perm.device)
#      54     mask[perm] = i
#      55
#
# RuntimeError: tabulate: failed to synchronize: cudaErrorAssert: device-side assert triggered

# %%
import matplotlib.pyplot as plt
import numpy as np

num_xaxis = 169 #args.epochs
fig, ax1 = plt.subplots()
x_axis = np.linspace(1,num_xaxis,num=num_xaxis)
color = 'tab:red'
ax1.set_xlabel('Epochs',fontsize=15)
ax1.set_ylabel('val_loss', color=color,fontsize=15)
ax1.plot(x_axis, val_loss_plot, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('val_acc', color=color,fontsize=15) 
ax2.plot(x_axis, val_acc_plot, color=color)
ax2.tick_params(axis='y', labelcolor=color)

ax1.set_title('SAGP-'+str(args.dataset),fontsize=15)

fig.tight_layout()
fig.show()
fig.savefig('./GNN_'+str(args.dataset)+'_'+str(epoch)+'.pdf',dpi=350)
# Out:
# /home/ywkim/pytorch_geometric/venv/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
